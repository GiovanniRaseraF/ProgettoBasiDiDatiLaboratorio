# %%
import json
import pandas as pd
import numpy as np
import os
import time
import pprint
import csv
import random
import string
import re

# %%
def serialize_json(folder, filename, data):
    if not os.path.exists(folder):
        os.makedirs(folder, exist_ok=True)
    with open(f"{folder}/{filename}", 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
        f.close()
    print(f"Data serialized to path: {folder}/{filename}")

def read_json(path):
    if os.path.exists(path):
        with open(path, "r", encoding="utf8") as file:
            data = json.load(file)
        print(f"Data read from path: {path}")
        return data
    else:
        print(f"No data found at path: {path}")
        return {}

# %%
maschi =read_json("CSV/ITGivenMale.json")
femmine =read_json("CSV/ITGivenFemale.json")

nomi = []
for persona in maschi:
    utente={}
    utente["nome"] = persona["name"]
    nomi.append(utente)
    
for persona in femmine:
    utente={}
    utente["nome"] = persona["name"]
    nomi.append(utente)    


with open('CSV/cognomi.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

cognomi = []
for user in data:
    if(user[0] != "Cognomi"):
        cognome={}
        cognome_to_clean = user[0].lower().capitalize()
        cognome["cognome"]= cognome_to_clean
        cognome["clean"]=  re.sub(r"[^a-zA-Z\s+]"," ",cognome_to_clean)
        cognomi.append(cognome)     
     
with open('CSV/Numeri_civici.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
indirizzi = []
for ind in data:
        indirizzo={}
        indirizzo["citta"]= ind[2].lower().capitalize()
        indirizzo["via"]=  re.sub(r"[^a-zA-Z\s+]"," ",ind[4].lower().capitalize())+" "+ind[5].lower().capitalize()+" "+ind[6]
        indirizzi.append(indirizzo)
# Out:
# Data read from path: ITGivenMale.json
# Data read from path: ITGivenFemale.json

# %%
colonne=["nome","cognome","clean","citta","via"]
registro=pd.DataFrame(columns=colonne)

# %%
cliente={}
for k in range(1,5000):
    x = random.randint(0,len(nomi)-1)
    y = random.randint(0,len(cognomi)-1)
    z = random.randint(0,len(indirizzi)-1)
    cliente['nome']= nomi[x]['nome']
    cliente['cognome'] = cognomi[y]['cognome']
    cliente['clean'] = cognomi[y]['clean']
    cliente['citta'] = indirizzi[z]['citta']
    cliente['via'] = indirizzi[z]['via']
    registro.loc[k] = cliente

registro[:100]
# Out:
#          nome      cognome        clean                    citta  \
# 1     Fidarma   Solombrino   Solombrino                  Maniago
# 2      Portos        Greco        Greco    Cervignano del friuli
# 3     Quinzia       Tunwal       Tunwal                 Travesio
# 4       Rinda  Arcidiacona  Arcidiacona                   Arzene
# 5    Miroslao     Caporale     Caporale       Capriva del friuli
# ..        ...          ...          ...                      ...
# 96     Alvaro     Frasheri     Frasheri   San daniele del friuli
# 97   Feliceta    Kandasamy    Kandasamy                  Trieste
# 98   Zannetto    Marafioti    Marafioti            Azzano decimo
# 99       Oler       Tarsia       Tarsia                  Trieste
# 100   Elpidio  Del vescovo  Del vescovo  San vito al tagliamento
#
#                              via
# 1        Via Tiziano vecellio 32
# 2    Piazza Guglielmo marconi 14
# 3                Via Forchiat 11
# 4                 Via Maiaroff 7
# 5                Via I maggio 12
# ..                           ...
# 96               Via Kennedy 104
# 97            Via Dell'eremo 146
# 98     Via Cesena scrovat inf. 2
# 99               Via San carlo 4
# 100             Viale Gramsci 19
#
# [100 rows x 5 columns]

# %%
dati_anagrafici = []
for row in registro.iterrows():
    contatto = {}
    n=row[1]['nome']
    c=row[1]['clean']
    ln = len(n)
    cn = len(c)
    maxl= (random.randint(1,ln-1))
    maxcl= (random.randint(1,cn-1))
    p1= c[0]+c[1].upper()+c[maxcl].upper()+n[0].upper()+n[1].upper()+n[maxl].upper()
    p2= str(random.randint(0,9))+str(random.randint(0,9))+random.choice(string.ascii_letters).upper()+str(random.randint(0,3))+str(random.randint(0,9))+random.choice(string.ascii_letters).upper()+str(random.randint(0,9))+str(random.randint(0,9))+str(random.randint(0,9))+random.choice(string.ascii_letters).upper()
    cf =p1+p2
    contatto["nome"]=n
    contatto["cognome"]=row[1]['cognome']
    contatto["codiceFiscale"]=cf
    contatto["citta"]=row[1]['citta']
    contatto["via"]=row[1]['via']
    dati_anagrafici.append(contatto)

print(dati_anagrafici[:10])
# Out:
# (1, nome                       Fidarma
# cognome                 Solombrino
# clean                   Solombrino
# citta                      Maniago
# via        Via Tiziano vecellio 32
# Name: 1, dtype: object)
# (2, nome                            Portos
# cognome                          Greco
# clean                            Greco
# citta            Cervignano del friuli
# via        Piazza Guglielmo marconi 14
# Name: 2, dtype: object)
# (3, nome               Quinzia
# cognome             Tunwal
# clean               Tunwal
# citta             Travesio
# via        Via Forchiat 11
# Name: 3, dtype: object)
# (4, nome                Rinda
# cognome       Arcidiacona
# clean         Arcidiacona
# citta              Arzene
# via        Via Maiaroff 7
# Name: 4, dtype: object)
# (5, nome                 Miroslao
# cognome              Caporale
# clean                Caporale
# citta      Capriva del friuli
# via           Via I maggio 12
# Name: 5, dtype: object)
# (6, nome               Iliana
# cognome             Diana
# clean               Diana
# citta               Udine
# via        Via Pozzuolo 8
# Name: 6, dtype: object)
# (7, nome                      Cosimino
# cognome                    Alarcio
# clean                      Alarcio
# citta                        Udine
# via        Via Prospero antonini 1
# Name: 7, dtype: object)
# (8, nome          Elfride
# cognome         Rollo
# clean           Rollo
# citta        Porpetto
# via        Via Roma 1
# Name: 8, dtype: object)
# (9, nome                  Gradita
# cognome             Anastasio
# clean               Anastasio
# citta             Spilimbergo
# via        Via Duca d'aosta 3
# Name: 9, dtype: object)
# (10, nome                     Sabina
# cognome                 Ananika
# clean                   Ananika
# citta                    Aviano
# via        Vicolo San martino 4
# Name: 10, dtype: object)
# (11, nome                        Giuffrida
# cognome                          Atif
# clean                            Atif
# citta      San martino al tagliamento
# via                   Via Domanins 19
# Name: 11, dtype: object)
# (12, nome              Rosarietta
# cognome               Pollio
# clean                 Pollio
# citta        Pasian di prato
# via        Via Basaldella 80
# Name: 12, dtype: object)
# (13, nome                  Bartolomeo
# cognome                Benvenuto
# clean                  Benvenuto
# citta                    Gorizia
# via        Via Campagna bassa 23
# Name: 13, dtype: object)
# (14, nome                  Corinna
# cognome              Pompucci
# clean                Pompucci
# citta                Lestizza
# via        Via Mortegliano 36
# Name: 14, dtype: object)
# (15, nome              Aldovino
# cognome            Altizio
# clean              Altizio
# citta      Mereto di tomba
# via        Via De marco 36
# Name: 15, dtype: object)
# (16, nome                          Bianchina
# cognome                      Compagnone
# clean                        Compagnone
# citta                            Sacile
# via        Viale San giovanni tempio 27
# Name: 16, dtype: object)
# (17, nome                  Dolcino
# cognome               Farella
# clean                 Farella
# citta       Roveredo in piano
# via        Via Xx settembre 1
# Name: 17, dtype: object)
# (18, nome                 Flavina
# cognome             Vadrucci
# clean               Vadrucci
# citta                 Muggia
# via        Via Strudthoff 20
# Name: 18, dtype: object)
# (19, nome                       Civita
# cognome                     Ahmad
# clean                       Ahmad
# citta      San daniele del friuli
# via              Via Nazionale 64
# Name: 19, dtype: object)
# (20, nome                 Medora
# cognome             Salaris
# clean               Salaris
# citta                 Udine
# via        Via Pordenone 27
# Name: 20, dtype: object)
# (21, nome           Desdemona
# cognome        Pettorino
# clean          Pettorino
# citta           Enemonzo
# via        Via Pradis 27
# Name: 21, dtype: object)
# (22, nome             Remondino
# cognome              Tucci
# clean                Tucci
# citta                Grado
# via        Via Aquileia 41
# Name: 22, dtype: object)
# (23, nome                     Fruttuoso
# cognome                      Muolo
# clean                        Muolo
# citta            Roveredo in piano
# via        Localita  Borgonuovo 51
# Name: 23, dtype: object)
# (24, nome              Moravio
# cognome      Thiyagarajah
# clean        Thiyagarajah
# citta            Bertiolo
# via        Via Tiepolo 30
# Name: 24, dtype: object)
# (25, nome                   Aureo
# cognome               Ogango
# clean                 Ogango
# citta                 Barcis
# via        Via Iv novembre 8
# Name: 25, dtype: object)
# (26, nome                 Walchirio
# cognome                 Taghar
# clean                   Taghar
# citta                   Majano
# via        Frazione Comerzo 17
# Name: 26, dtype: object)
# (27, nome                   Falando
# cognome               Butticci
# clean                 Butticci
# citta               Fiumicello
# via        Via 3 busti, dei 10
# Name: 27, dtype: object)
# (28, nome                  Nellina
# cognome               Grazian
# clean                 Grazian
# citta      Lignano sabbiadoro
# via            Via Giardini 4
# Name: 28, dtype: object)
# (29, nome                             Corebo
# cognome                         Mustich
# clean                           Mustich
# citta                            Muggia
# via        Darsella Di s. bartolomeo 22
# Name: 29, dtype: object)
# (30, nome                     Gianfranco
# cognome                     Viterbo
# clean                       Viterbo
# citta             San pier d'isonzo
# via        Via Pre' tita falzari 23
# Name: 30, dtype: object)
# (31, nome                Novilia
# cognome          Del medico
# clean            Del medico
# citta               Buttrio
# via        Via Degli orti 5
# Name: 31, dtype: object)
# (32, nome                          Zena
# cognome                   Predescu
# clean                     Predescu
# citta      San vito al tagliamento
# via                Via De rocco 63
# Name: 32, dtype: object)
# (33, nome                    Orildo
# cognome              Christian
# clean                Christian
# citta                   Majano
# via        Frazione Comerzo 72
# Name: 33, dtype: object)
# (34, nome                 Donella
# cognome               Akhsay
# clean                 Akhsay
# citta          Villa santina
# via        Via C.battisti 63
# Name: 34, dtype: object)
# (35, nome                    Fenelia
# cognome             Islam mamun
# clean               Islam mamun
# citta                   Gorizia
# via        Via Carlo favetti 14
# Name: 35, dtype: object)
# (36, nome                 Rosvaldo
# cognome          De dominicis
# clean            De dominicis
# citta                  Osoppo
# via        Via Brannenburg 19
# Name: 36, dtype: object)
# (37, nome                       Rubes
# cognome                  Porcino
# clean                    Porcino
# citta      San giorgio di nogaro
# via                  Via Roma 22
# Name: 37, dtype: object)
# (38, nome                 Bisio
# cognome          Primavera
# clean            Primavera
# citta      Marano lagunare
# via          Via Strozzi 7
# Name: 38, dtype: object)
# (39, nome                  Licio
# cognome    Cuasay abarintos
# clean      Cuasay abarintos
# citta             Pordenone
# via             Via Zara 14
# Name: 39, dtype: object)
# (40, nome                         Caruso
# cognome             Metrillo iponla
# clean               Metrillo iponla
# citta                         Udine
# via        Via Monte san gabriele 4
# Name: 40, dtype: object)
# (41, nome                    Bardomiano
# cognome                    Gambala
# clean                      Gambala
# citta                    Socchieve
# via        Via Guglielmo marconi 5
# Name: 41, dtype: object)
# (42, nome           Stellamaris
# cognome              Mizzi
# clean                Mizzi
# citta            Cordenons
# via        Via V. carli 25
# Name: 42, dtype: object)
# (43, nome                 Osema
# cognome              Baber
# clean                Baber
# citta           Staranzano
# via        Via Trieste 113
# Name: 43, dtype: object)
# (44, nome                Liberina
# cognome            Arigliano
# clean              Arigliano
# citta                  Udine
# via        Via Del boscat 56
# Name: 44, dtype: object)
# (45, nome                             Igeo
# cognome                           Ali
# clean                             Ali
# citta                        Lusevera
# via        Frazione Villanova d.g. 56
# Name: 45, dtype: object)
# (46, nome                Emerino
# cognome               Setti
# clean                 Setti
# citta           San quirino
# via        Via Marconi g. 7
# Name: 46, dtype: object)
# (47, nome                      Algerino
# cognome                 Pecoriello
# clean                   Pecoriello
# citta      San vito al tagliamento
# via                Via Cipressi 18
# Name: 47, dtype: object)
# (48, nome                   Zoia
# cognome             Olteanu
# clean               Olteanu
# citta            Tavagnacco
# via        Via G. mameli 13
# Name: 48, dtype: object)
# (49, nome                    Baldasarre
# cognome                 D'ippolito
# clean                   D ippolito
# citta                  Vito d'asio
# via        Via Regina margherita 4
# Name: 49, dtype: object)
# (50, nome            Finalbo
# cognome           Majji
# clean             Majji
# citta              Ruda
# via        Via Udine 34
# Name: 50, dtype: object)
# (51, nome                Zopito
# cognome           Abarquez
# clean             Abarquez
# citta                Nimis
# via        Corte Trieste 6
# Name: 51, dtype: object)
# (52, nome                     Saul
# cognome               Mannino
# clean                 Mannino
# citta      Lignano sabbiadoro
# via           Calle Bruegel 5
# Name: 52, dtype: object)
# (53, nome                    Tullo
# cognome               Ramires
# clean                 Ramires
# citta           Fontanafredda
# via        Via P. veronese 23
# Name: 53, dtype: object)
# (54, nome                   Andrietto
# cognome                 Lemkadem
# clean                   Lemkadem
# citta      San giorgio di nogaro
# via              Via Di mezzo 10
# Name: 54, dtype: object)
# (55, nome             Giangiacomo
# cognome             Epicochi
# clean               Epicochi
# citta                  Udine
# via        Via Bariglaria 67
# Name: 55, dtype: object)
# (56, nome                            Cleofina
# cognome                         Crimaldi
# clean                           Crimaldi
# citta      San giorgio della richinvelda
# via                   Via Spilimbergo 35
# Name: 56, dtype: object)
# (57, nome                Odilla
# cognome    Tarantino girau
# clean      Tarantino girau
# citta          Spilimbergo
# via        Via San paolo 1
# Name: 57, dtype: object)
# (58, nome            Pietrantonio
# cognome       Garcia vazquez
# clean         Garcia vazquez
# citta      Gemona del friuli
# via            Via Vuarbe 28
# Name: 58, dtype: object)
# (59, nome                  Roma
# cognome            Paduano
# clean              Paduano
# citta      Pasian di prato
# via          Via Milano 37
# Name: 59, dtype: object)
# (60, nome                  Belardino
# cognome                   Pirri
# clean                     Pirri
# citta                Staranzano
# via        Via Grazia deledda 1
# Name: 60, dtype: object)
# (61, nome                Evino
# cognome    Van der heiden
# clean      Van der heiden
# citta              Budoia
# via        Via Panizzut 8
# Name: 61, dtype: object)
# (62, nome            Mattia
# cognome        Murgano
# clean          Murgano
# citta         Resiutta
# via        Via Roma 26
# Name: 62, dtype: object)
# (63, nome                        Edvino
# cognome                    Memmola
# clean                      Memmola
# citta                        Udine
# via        Via Daniele cernazai 23
# Name: 63, dtype: object)
# (64, nome                    Marianita
# cognome               Maggialetti
# clean                 Maggialetti
# citta                     Trieste
# via        Punto Franco vecchio 8
# Name: 64, dtype: object)
# (65, nome                 Lucindo
# cognome            Polverino
# clean              Polverino
# citta                 Gonars
# via        Via P. diacono 10
# Name: 65, dtype: object)
# (66, nome                   Olivanna
# cognome                  Baziuk
# clean                    Baziuk
# citta                    Zuglio
# via        Via Nicola grassi 22
# Name: 66, dtype: object)
# (67, nome                  Vettorino
# cognome                   Picco
# clean                     Picco
# citta                   Sagrado
# via        Via F.lli mucchiut 7
# Name: 67, dtype: object)
# (68, nome              Calisto
# cognome      Nieto ferrer
# clean        Nieto ferrer
# citta            Tolmezzo
# via        Via Pissebus 2
# Name: 68, dtype: object)
# (69, nome              Giacinta
# cognome           Monopoli
# clean             Monopoli
# citta               Chions
# via        Via S. marco 27
# Name: 69, dtype: object)
# (70, nome                   Dorigo
# cognome        Selvakulandran
# clean          Selvakulandran
# citta                 Gorizia
# via        Vicolo Del guado 5
# Name: 70, dtype: object)
# (71, nome                        Bastianina
# cognome                       Quadraro
# clean                         Quadraro
# citta           San daniele del friuli
# via        Via Fratelli pischiutta 119
# Name: 71, dtype: object)
# (72, nome              Mordechai
# cognome          Muscogiuri
# clean            Muscogiuri
# citta               Zoppola
# via        Via Zoppolana 20
# Name: 72, dtype: object)
# (73, nome                  Palmarosa
# cognome                Perfetti
# clean                  Perfetti
# citta                 Pordenone
# via        Via Azzano decimo 34
# Name: 73, dtype: object)
# (74, nome                      Amodeo
# cognome            Della tommasa
# clean              Della tommasa
# citta                  Rivignano
# via        Via Giordano bruno 13
# Name: 74, dtype: object)
# (75, nome             Umberta
# cognome           Masala
# clean             Masala
# citta           Pagnacco
# via        Via Alnicco 3
# Name: 75, dtype: object)
# (76, nome                  Alboina
# cognome    Calabrese aversini
# clean      Calabrese aversini
# citta                   Lauco
# via        Frazione Vinaio 36
# Name: 76, dtype: object)
# (77, nome                Evenzio
# cognome                Rosa
# clean                  Rosa
# citta           Mortegliano
# via        Via S.antonio 35
# Name: 77, dtype: object)
# (78, nome             Alderice
# cognome        Laurentaci
# clean          Laurentaci
# citta                Buja
# via        Via Sclusãœz 6
# Name: 78, dtype: object)
# (79, nome                   Mea
# cognome            Bassani
# clean              Bassani
# citta              Attimis
# via        Via Canin m. 10
# Name: 79, dtype: object)
# (80, nome                Vincenzina
# cognome                  Iyamu
# clean                    Iyamu
# citta                   Aviano
# via        Via Monte tremol 20
# Name: 80, dtype: object)
# (81, nome                Galieno
# cognome    O'farrill garcia
# clean      O farrill garcia
# citta                 Udine
# via          Via Attimis 33
# Name: 81, dtype: object)
# (82, nome               Roselino
# cognome            Mihaloiu
# clean              Mihaloiu
# citta                Budoia
# via        Via San tome' 14
# Name: 82, dtype: object)
# (83, nome                   Ina
# cognome             Cramis
# clean               Cramis
# citta             Latisana
# via        Via Del varmo 0
# Name: 83, dtype: object)
# (84, nome                   Flora
# cognome              Osarobo
# clean                Osarobo
# citta                Trieste
# via        Via Dei gravisi 4
# Name: 84, dtype: object)
# (85, nome                  Libertas
# cognome                   Rhao
# clean                     Rhao
# citta                  Paularo
# via        Case sparse Baret 1
# Name: 85, dtype: object)
# (86, nome                      Zelmo
# cognome                Zaccaria
# clean                  Zaccaria
# citta      Santa maria la longa
# via            Via G. ellero 12
# Name: 86, dtype: object)
# (87, nome                        Ilde
# cognome                 Gaudiano
# clean                   Gaudiano
# citta            Marano lagunare
# via        Via Raddi gerolamo 12
# Name: 87, dtype: object)
# (88, nome               Morgana
# cognome    De nicola lezzi
# clean      De nicola lezzi
# citta                Nimis
# via           Via Tamar 13
# Name: 88, dtype: object)
# (89, nome                           Forleo
# cognome    Sri brahmana mudiyanselage
# clean      Sri brahmana mudiyanselage
# citta             Fogliano redipuglia
# via                     Via Friuli 12
# Name: 89, dtype: object)
# (90, nome              Laurentina
# cognome            Tassielli
# clean              Tassielli
# citta      Tramonti di sopra
# via           Via Venezia 14
# Name: 90, dtype: object)
# (91, nome                   Armandina
# cognome                  Machara
# clean                    Machara
# citta                  Rivignano
# via        Via Nazzario sauro 11
# Name: 91, dtype: object)
# (92, nome                      Zenio
# cognome                Caliendo
# clean                  Caliendo
# citta                   Sagrado
# via        Salita San michele 1
# Name: 92, dtype: object)
# (93, nome                Comunarda
# cognome          Santoniccolo
# clean            Santoniccolo
# citta                   Udine
# via        Via Portogruaro 24
# Name: 93, dtype: object)
# (94, nome            Francesco
# cognome             Ceino
# clean               Ceino
# citta           Cordenons
# via        Via B. croce 9
# Name: 94, dtype: object)
# (95, nome                      Argea
# cognome                 Palazzi
# clean                   Palazzi
# citta               Premariacco
# via        Via Borgo di sopra 5
# Name: 95, dtype: object)
# (96, nome                       Alvaro
# cognome                  Frasheri
# clean                    Frasheri
# citta      San daniele del friuli
# via               Via Kennedy 104
# Name: 96, dtype: object)
# (97, nome                 Feliceta
# cognome             Kandasamy
# clean               Kandasamy
# citta                 Trieste
# via        Via Dell'eremo 146
# Name: 97, dtype: object)
# (98, nome                        Zannetto
# cognome                    Marafioti
# clean                      Marafioti
# citta                  Azzano decimo
# via        Via Cesena scrovat inf. 2
# Name: 98, dtype: object)
# (99, nome                  Oler
# cognome             Tarsia
# clean               Tarsia
# citta              Trieste
# via        Via San carlo 4
# Name: 99, dtype: object)
# (100, nome                       Elpidio
# cognome                Del vescovo
# clean                  Del vescovo
# citta      San vito al tagliamento
# via               Viale Gramsci 19
# Name: 100, dtype: object)
# (101, nome            Feliciola
# cognome          Conforti
# clean            Conforti
# citta               Ovaro
# via        Via Nungulas 4
# Name: 101, dtype: object)
# (102, nome                Maia
# cognome    Grassi grande
# clean      Grassi grande
# citta          Pordenone
# via        Via Casarsa 7
# Name: 102, dtype: object)
# (103, nome               Desiderio
# cognome              Solomon
# clean                Solomon
# citta             Monfalcone
# via        Via Del mulino 10
# Name: 103, dtype: object)
# (104, nome                      Iago
# cognome                 Carlin
# clean                   Carlin
# citta                Pordenone
# via        Via Monte grappa 13
# Name: 104, dtype: object)
# (105, nome                     Olves
# cognome    Del solar fernandez
# clean      Del solar fernandez
# citta               Monfalcone
# via          Via Xxv aprile 35
# Name: 105, dtype: object)
# (106, nome             Lillia
# cognome          Conteh
# clean            Conteh
# citta       Mortegliano
# via        Via Udine 23
# Name: 106, dtype: object)
# (107, nome             Eritreo
# cognome         Petrella
# clean           Petrella
# citta             Muggia
# via        Largo Sauro 5
# Name: 107, dtype: object)
# (108, nome                  Nunzio
# cognome                Zatti
# clean                  Zatti
# citta                Maniago
# via        Via Tesana sud 14
# Name: 108, dtype: object)
# (109, nome                Palmina
# cognome           Chiriatti
# clean             Chiriatti
# citta                Meduno
# via        Via Vi maggio 11
# Name: 109, dtype: object)
# (110, nome                  Adamaria
# cognome                Luggeri
# clean                  Luggeri
# citta               Remanzacco
# via        Via Santo stefano 7
# Name: 110, dtype: object)
# (111, nome                    Misiana
# cognome              Husein ali
# clean                Husein ali
# citta      San canzian d'isonzo
# via             Via I maggio 30
# Name: 111, dtype: object)
# (112, nome                Massimilla
# cognome                Atienza
# clean                  Atienza
# citta                  Paularo
# via        Via Della gronda 16
# Name: 112, dtype: object)
# (113, nome         Eglantina
# cognome    Antoszewska
# clean      Antoszewska
# citta            Fanna
# via        Via Bruni 2
# Name: 113, dtype: object)
# (114, nome                 Antonello
# cognome              Premkumar
# clean                Premkumar
# citta                 Frisanco
# via        Borgo Valdifrina 29
# Name: 114, dtype: object)
# (115, nome                    Ivette
# cognome              Circolone
# clean                Circolone
# citta                   Majano
# via        Frazione Casasola 4
# Name: 115, dtype: object)
# (116, nome            Alfonsina
# cognome         Giorgelli
# clean           Giorgelli
# citta            Tolmezzo
# via        Piazza Centa 6
# Name: 116, dtype: object)
# (117, nome                      Antonello
# cognome                      Ferenc
# clean                        Ferenc
# citta                       Trieste
# via        Via Parenzan bernardin 1
# Name: 117, dtype: object)
# (118, nome              Salvetto
# cognome              Gurra
# clean                Gurra
# citta              Gorizia
# via        Corso Italia 49
# Name: 118, dtype: object)
# (119, nome                 Brunino
# cognome                Lo re
# clean                  Lo re
# citta      Gradisca d'isonzo
# via          Via Aquileia 55
# Name: 119, dtype: object)
# (120, nome               Idiana
# cognome           Gjepali
# clean             Gjepali
# citta            Lestizza
# via        Piazza Verdi 9
# Name: 120, dtype: object)
# (121, nome                Oscarino
# cognome            La tegola
# clean              La tegola
# citta      Gemona del friuli
# via         Via Bersaglio 14
# Name: 121, dtype: object)
# (122, nome                     Eupremia
# cognome                  Calcagno
# clean                    Calcagno
# citta                     Trieste
# via        Strada Per longera 127
# Name: 122, dtype: object)
# (123, nome                              Primetta
# cognome                             Zanfir
# clean                               Zanfir
# citta                             Frisanco
# via        Localita  Crocera s. floriano 3
# Name: 123, dtype: object)
# (124, nome                 Lucrezio
# cognome              Andersen
# clean                Andersen
# citta            Campoformido
# via        Via Napoleonica 55
# Name: 124, dtype: object)
# (125, nome                Novilio
# cognome              Stursi
# clean                Stursi
# citta      Savogna d'isonzo
# via        Via 24 maggio 26
# Name: 125, dtype: object)
# (126, nome                 Marlena
# cognome             Famulari
# clean               Famulari
# citta      Gemona del friuli
# via             Via Baldo 82
# Name: 126, dtype: object)
# (127, nome                     Onetto
# cognome                  Ciocca
# clean                    Ciocca
# citta                   Trieste
# via        Via San sebastiano 2
# Name: 127, dtype: object)
# (128, nome                      Jella
# cognome                 Nortier
# clean                   Nortier
# citta      Pasiano di pordenone
# via            Via Dei gelsi 14
# Name: 128, dtype: object)
# (129, nome                   Abbondina
# cognome                   Pedana
# clean                     Pedana
# citta                     Caneva
# via        Via General cantore 8
# Name: 129, dtype: object)
# (130, nome                  Velledo
# cognome                 Tecci
# clean                   Tecci
# citta                 Trieste
# via        Via Praga marco 24
# Name: 130, dtype: object)
# (131, nome                  Gordiano
# cognome                 Serian
# clean                   Serian
# citta            Villa santina
# via        Viale Degli eroi 35
# Name: 131, dtype: object)
# (132, nome                            Raimondo
# cognome               D'argenio fabrizio
# clean                 D argenio fabrizio
# citta                        Vito d'asio
# via        Piazza Conte giacomo ceconi 1
# Name: 132, dtype: object)
# (133, nome                    Riguccio
# cognome                   Palisi
# clean                     Palisi
# citta      Cervignano del friuli
# via            Via Monfalcone 21
# Name: 133, dtype: object)
# (134, nome               Nicoletto
# cognome            Monteduro
# clean              Monteduro
# citta       Reana del rojale
# via        Via P. collino 14
# Name: 134, dtype: object)
# (135, nome                 Egida
# cognome    De vita baccaro
# clean      De vita baccaro
# citta                Visco
# via        Via G. pazzut 4
# Name: 135, dtype: object)
# (136, nome             Geralda
# cognome         Pinnelli
# clean           Pinnelli
# citta            Maniago
# via        Via Molini 49
# Name: 136, dtype: object)
# (137, nome                Esule
# cognome         Sparviero
# clean           Sparviero
# citta               Udine
# via        Via Treviso 46
# Name: 137, dtype: object)
# (138, nome                       Osmelia
# cognome                    Alfonso
# clean                      Alfonso
# citta      San vito al tagliamento
# via            Localita  Patocco 6
# Name: 138, dtype: object)
# (139, nome            Gennarino
# cognome        Vintilescu
# clean          Vintilescu
# citta             Dignano
# via        Via Maseris 21
# Name: 139, dtype: object)
# (140, nome                                                Liseo
# cognome                                           Marrano
# clean                                             Marrano
# citta                                          Torviscosa
# via        Via Fornelli di sotto e dell' arrodola nuova 3
# Name: 140, dtype: object)
# (141, nome                Amelino
# cognome              Konadu
# clean                Konadu
# citta               Ampezzo
# via        Via Nazionale 65
# Name: 141, dtype: object)
# (142, nome            Corinna
# cognome          Sacino
# clean            Sacino
# citta            Meduno
# via        Via Nuova 41
# Name: 142, dtype: object)
# (143, nome                           Elvida
# cognome                       Giudice
# clean                         Giudice
# citta                        Lusevera
# via        Frazione Villanova d.g. 98
# Name: 143, dtype: object)
# (144, nome                        Lenin
# cognome                     Memmi
# clean                       Memmi
# citta      Morsano al tagliamento
# via                 Via Venezia 1
# Name: 144, dtype: object)
# (145, nome                         Oride
# cognome                Colamartino
# clean                  Colamartino
# citta                      Sagrado
# via        Via Carlo luigi bozzi 8
# Name: 145, dtype: object)
# (146, nome               Fenizio
# cognome             Arnisi
# clean               Arnisi
# citta              Ronchis
# via        Corso Italia 33
# Name: 146, dtype: object)
# (147, nome                Prassede
# cognome              De majo
# clean                De majo
# citta                Trieste
# via        Via Dell'eremo 51
# Name: 147, dtype: object)
# (148, nome                 Ortensia
# cognome                 Perna
# clean                   Perna
# citta                 Trieste
# via        Via San nazario 87
# Name: 148, dtype: object)
# (149, nome                Giammauro
# cognome             De tuglie
# clean               De tuglie
# citta              Remanzacco
# via        Via G. monfredo 51
# Name: 149, dtype: object)
# (150, nome                        Silene
# cognome                      Vaira
# clean                        Vaira
# citta      San vito al tagliamento
# via                 Via Battisti 9
# Name: 150, dtype: object)
# (151, nome                 Zerbina
# cognome              Varallo
# clean                Varallo
# citta                Ragogna
# via        Via S.giovanni 42
# Name: 151, dtype: object)
# (152, nome                     Olidia
# cognome                    Paci
# clean                      Paci
# citta      Ronchi dei legionari
# via        Via Dell'aeroporto 2
# Name: 152, dtype: object)
# (153, nome                 Patroclo
# cognome             Frontisti
# clean               Frontisti
# citta                   Medea
# via        Via Xxiv maggio 10
# Name: 153, dtype: object)
# (154, nome                            Milvano
# cognome                    Nieto ferrer
# clean                      Nieto ferrer
# citta                            Muggia
# via        Via Di s. barbara strad. a 2
# Name: 154, dtype: object)
# (155, nome                      Giulivo
# cognome                  De sicot
# clean                    De sicot
# citta      Palazzolo dello stella
# via                Via Tresara 10
# Name: 155, dtype: object)
# (156, nome               Davinio
# cognome              Ahmad
# clean                Ahmad
# citta           Monfalcone
# via        Via C.goldoni 7
# Name: 156, dtype: object)
# (157, nome               Natalizia
# cognome              Dumitru
# clean                Dumitru
# citta              Tricesimo
# via        Via Pontebbana 20
# Name: 157, dtype: object)
# (158, nome               Ermido
# cognome         Tavernese
# clean           Tavernese
# citta             Carlino
# via        Strada Fisch 4
# Name: 158, dtype: object)
# (159, nome            Angiolino
# cognome         Velupulle
# clean           Velupulle
# citta             Paularo
# via        Via Tavella 28
# Name: 159, dtype: object)
# (160, nome              Ostenda
# cognome             Nasar
# clean               Nasar
# citta                Buja
# via        Via Madonna 59
# Name: 160, dtype: object)
# (161, nome                Ortigia
# cognome              Okpara
# clean                Okpara
# citta      Reana del rojale
# via        Via San marco 24
# Name: 161, dtype: object)
# (162, nome               Tindara
# cognome          Cassigoli
# clean            Cassigoli
# citta          Martignacco
# via        Via Leopardi 10
# Name: 162, dtype: object)
# (163, nome                Terzilio
# cognome     Bustamante lorca
# clean       Bustamante lorca
# citta         Forni di sopra
# via        Via Nazionale 196
# Name: 163, dtype: object)
# (164, nome                 Dianora
# cognome                 Miah
# clean                   Miah
# citta      Gemona del friuli
# via            Via Cavour 18
# Name: 164, dtype: object)
# (165, nome                    Iole
# cognome              Funiati
# clean                Funiati
# citta                 Sutrio
# via        Via San nicolo' 7
# Name: 165, dtype: object)
# (166, nome                 Solferino
# cognome                Devynck
# clean                  Devynck
# citta                 Lestizza
# via        Via San giovanni 35
# Name: 166, dtype: object)
# (167, nome                         Peppe
# cognome                    Soranno
# clean                      Soranno
# citta            Roveredo in piano
# via        Localita  Borgonuovo 65
# Name: 167, dtype: object)
# (168, nome                                 Plavo
# cognome                           Frontino
# clean                             Frontino
# citta                                Udine
# via        Via S.margherita del gruagno 53
# Name: 168, dtype: object)
# (169, nome                    Solimano
# cognome         Muthuna acharige
# clean           Muthuna acharige
# citta                     Muggia
# via        Localita  Chiampore 1
# Name: 169, dtype: object)
# (170, nome              Liviano
# cognome              Toro
# clean                Toro
# citta            Tarvisio
# via        Via Prisnig 96
# Name: 170, dtype: object)
# (171, nome        Melchisedeo
# cognome       Sanfelice
# clean         Sanfelice
# citta       Spilimbergo
# via        Via Isonzo 5
# Name: 171, dtype: object)
# (172, nome                        Gilmo
# cognome        Pizzo stancampiano
# clean          Pizzo stancampiano
# citta                    Tolmezzo
# via        Via Divisione julia 55
# Name: 172, dtype: object)
# (173, nome           Chiarella
# cognome        Guariglia
# clean          Guariglia
# citta      Azzano decimo
# via         Via Colle 22
# Name: 173, dtype: object)
# (174, nome                   Nelda
# cognome            Panarelli
# clean              Panarelli
# citta            Vito d'asio
# via        Localita  Mont 48
# Name: 174, dtype: object)
# (175, nome                  Felsina
# cognome               Mainini
# clean                 Mainini
# citta      Lignano sabbiadoro
# via        Piazza Del sole 62
# Name: 175, dtype: object)
# (176, nome                  Fiandra
# cognome           Facchinetti
# clean             Facchinetti
# citta                Codroipo
# via        Via Xxiv maggio 56
# Name: 176, dtype: object)
# (177, nome                   Aloise
# cognome            Muscogiuri
# clean              Muscogiuri
# citta                 Zoppola
# via        Via Pescincanna 22
# Name: 177, dtype: object)
# (178, nome          Annarosa
# cognome         Isibor
# clean           Isibor
# citta         Brugnera
# via        Via Prata 5
# Name: 178, dtype: object)
# (179, nome                      Gelasia
# cognome                     Tsvar
# clean                       Tsvar
# citta                     Trieste
# via        Via Del castelliere 12
# Name: 179, dtype: object)
# (180, nome              Relino
# cognome        Selvarolo
# clean          Selvarolo
# citta           Frisanco
# via        Borgo Rioni 1
# Name: 180, dtype: object)
# (181, nome                             Renato
# cognome            Alves de faria silva
# clean              Alves de faria silva
# citta                           Gorizia
# via        Via Gian lorenzo cipriani 25
# Name: 181, dtype: object)
# (182, nome             Panfilo
# cognome        Tartarini
# clean          Tartarini
# citta          Trasaghis
# via        Via Fontana 6
# Name: 182, dtype: object)
# (183, nome                        Gaspare
# cognome              Renna chillino
# clean                Renna chillino
# citta                    Torviscosa
# via        Stradone Zuino nord 4446
# Name: 183, dtype: object)
# (184, nome                    Floridia
# cognome                Leporatti
# clean                  Leporatti
# citta                    Gorizia
# via        Via Dei garzarolli 86
# Name: 184, dtype: object)
# (185, nome                 Arconte
# cognome            Colacicco
# clean              Colacicco
# citta                Trieste
# via        Via Costalunga 80
# Name: 185, dtype: object)
# (186, nome            Dannunzio
# cognome          Contaldo
# clean            Contaldo
# citta          Fiumicello
# via        Via Cortona 12
# Name: 186, dtype: object)
# (187, nome                 Sarita
# cognome          Maffezzoli
# clean            Maffezzoli
# citta                 Resia
# via        Via Progresso 16
# Name: 187, dtype: object)
# (188, nome               Paris
# cognome      Sabjifarosh
# clean        Sabjifarosh
# citta           Tarvisio
# via        Via A. diaz 9
# Name: 188, dtype: object)
# (189, nome        Martiniano
# cognome        Mellone
# clean          Mellone
# citta       Tavagnacco
# via        Via Dante 7
# Name: 189, dtype: object)
# (190, nome                   Nanni
# cognome         Mendez ortiz
# clean           Mendez ortiz
# citta      San vito al torre
# via           Via Cividale 3
# Name: 190, dtype: object)
# (191, nome                  Arfrosina
# cognome               Mascarani
# clean                 Mascarani
# citta             Azzano decimo
# via        Via Capo di sotto 11
# Name: 191, dtype: object)
# (192, nome                     Almiro
# cognome         Quarta cazzella
# clean           Quarta cazzella
# citta                  Torreano
# via        Localita  Tamoris 14
# Name: 192, dtype: object)
# (193, nome                         Tomeo
# cognome                      Emara
# clean                        Emara
# citta                      Trieste
# via        Via Valerio alfonso 110
# Name: 193, dtype: object)
# (194, nome              Lombardo
# cognome            Treglia
# clean              Treglia
# citta                Udine
# via        Via Marsala 212
# Name: 194, dtype: object)
# (195, nome                 Curzia
# cognome            Nadarasa
# clean              Nadarasa
# citta                 Nimis
# via        Via Braiduzze 18
# Name: 195, dtype: object)
# (196, nome                 Flamina
# cognome                Nikaj
# clean                  Nikaj
# citta      Doberdo' del lago
# via           Via Vallone 12
# Name: 196, dtype: object)
# (197, nome                      Polluce
# cognome                     Spena
# clean                       Spena
# citta                      Muggia
# via        Localita  S. andrea 12
# Name: 197, dtype: object)
# (198, nome                        Benino
# cognome                     Friuli
# clean                       Friuli
# citta      San vito al tagliamento
# via                Via De rocco 37
# Name: 198, dtype: object)
# (199, nome                        Armena
# cognome                   Cerasino
# clean                     Cerasino
# citta      San vito al tagliamento
# via                  Via Oderzo 12
# Name: 199, dtype: object)
# (200, nome                Dalmata
# cognome           Nicolella
# clean             Nicolella
# citta                Osoppo
# via        Via Garibaldi 51
# Name: 200, dtype: object)
# (201, nome                  Iovina
# cognome              Perdomo
# clean                Perdomo
# citta          Azzano decimo
# via        Via Degli olmi 28
# Name: 201, dtype: object)
# (202, nome                   Bertoldo
# cognome             Dissanayake
# clean               Dissanayake
# citta      San canzian d'isonzo
# via        Via Ris. s. sabba 31
# Name: 202, dtype: object)
# (203, nome                  Artemisia
# cognome                  Rudert
# clean                    Rudert
# citta                   Trieste
# via        Vicolo Delle rose 23
# Name: 203, dtype: object)
# (204, nome               Gemisto
# cognome    Duarte ferreira
# clean      Duarte ferreira
# citta          Vito d'asio
# via        Via Tolmezzo 39
# Name: 204, dtype: object)
# (205, nome                   Palladino
# cognome             Pastorekova'
# clean               Pastorekova
# citta      Casarsa della delizia
# via                  Via Sile 15
# Name: 205, dtype: object)
# (206, nome                  Amleta
# cognome             Saltarel
# clean               Saltarel
# citta          Prato carnico
# via        Frazione Prico 14
# Name: 206, dtype: object)
# (207, nome                Salviano
# cognome                 Idda
# clean                   Idda
# citta          Fontanafredda
# via        Via V. bellini 42
# Name: 207, dtype: object)
# (208, nome               Furtunata
# cognome             Rossanda
# clean               Rossanda
# citta                Zoppola
# via        Via Pontebbana 12
# Name: 208, dtype: object)
# (209, nome             Gisello
# cognome     Barbalinardo
# clean       Barbalinardo
# citta        San quirino
# via        Via Cesiol 21
# Name: 209, dtype: object)
# (210, nome              Feride
# cognome       Acquasanta
# clean         Acquasanta
# citta           Latisana
# via        Via Forte 101
# Name: 210, dtype: object)
# (211, nome                         Varnero
# cognome                        Falda
# clean                          Falda
# citta                     Monfalcone
# via        Androna C.de franceschi 1
# Name: 211, dtype: object)
# (212, nome                    Viviano
# cognome                 Schiro'
# clean                   Schiro
# citta         San pier d'isonzo
# via        Via Don giacomuzzi 1
# Name: 212, dtype: object)
# (213, nome                 Clarissa
# cognome             Naccarato
# clean               Naccarato
# citta                  Porcia
# via        Via Della centa 28
# Name: 213, dtype: object)
# (214, nome              Rebecca
# cognome         Bellanova
# clean           Bellanova
# citta               Dogna
# via        Via Montasio 1
# Name: 214, dtype: object)
# (215, nome                            Lodovico
# cognome                       Pizzichini
# clean                         Pizzichini
# citta                            Trieste
# via        Via San francesco d'assisi 23
# Name: 215, dtype: object)
# (216, nome                Altomare
# cognome           Eccellente
# clean             Eccellente
# citta          Villa santina
# via        Via C.battisti 39
# Name: 216, dtype: object)
# (217, nome                 Amberta
# cognome           Cominceanu
# clean             Cominceanu
# citta            Spilimbergo
# via        Via T. vecellio 1
# Name: 217, dtype: object)
# (218, nome                  Rosiano
# cognome                Pranzo
# clean                  Pranzo
# citta        Corno di rosazzo
# via        Via Forum julii 28
# Name: 218, dtype: object)
# (219, nome               Vilna
# cognome          Cirelli
# clean            Cirelli
# citta               Buja
# via        Via Avilla 60
# Name: 219, dtype: object)
# (220, nome               Orvieta
# cognome            Lazzari
# clean              Lazzari
# citta             Tarcento
# via        Via A.angeli 67
# Name: 220, dtype: object)
# (221, nome                 Erasmo
# cognome               Nitto
# clean                 Nitto
# citta              Lestizza
# via        Via Basiliano 10
# Name: 221, dtype: object)
# (222, nome                                 Faida
# cognome                            Ninfole
# clean                              Ninfole
# citta                              Trieste
# via        Localita  S,m,m, superiore 1254
# Name: 222, dtype: object)
# (223, nome                           Memmo
# cognome                   Trifiletti
# clean                     Trifiletti
# citta          San giorgio di nogaro
# via        Via Di toppo vasserman 71
# Name: 223, dtype: object)
# (224, nome                Noradino
# cognome               Ascone
# clean                 Ascone
# citta          Fontanafredda
# via        Via S. pellico 91
# Name: 224, dtype: object)
# (225, nome           Bonfiglio
# cognome       Pinnellini
# clean         Pinnellini
# citta           Enemonzo
# via        Via Mulinut 1
# Name: 225, dtype: object)
# (226, nome                     Aster
# cognome                Tassone
# clean                  Tassone
# citta                   Caneva
# via        Via Luigi cadorna 6
# Name: 226, dtype: object)
# (227, nome               Fiorinta
# cognome            De bonis
# clean              De bonis
# citta              Latisana
# via        Via Tisanella 43
# Name: 227, dtype: object)
# (228, nome                       Arcide
# cognome                    Thioye
# clean                      Thioye
# citta             Mereto di tomba
# via        Via Domenico bertoli 7
# Name: 228, dtype: object)
# (229, nome                     Lunella
# cognome                 Guerrier
# clean                   Guerrier
# citta      Cervignano del friuli
# via              Via Aquileia 11
# Name: 229, dtype: object)
# (230, nome              Finuccio
# cognome             Kaluza
# clean               Kaluza
# citta            Pordenone
# via        Via Bellasio 58
# Name: 230, dtype: object)
# (231, nome                                       Annito
# cognome                                  Mohammed
# clean                                    Mohammed
# citta            San dorligo della valle - dolina
# via        Frazione San giuseppe della chiusa 123
# Name: 231, dtype: object)
# (232, nome                      Olerio
# cognome                 Spinozzi
# clean                   Spinozzi
# citta      Casarsa della delizia
# via        Via Dell'artigliere 1
# Name: 232, dtype: object)
# (233, nome                  Olivetta
# cognome                 Naseri
# clean                   Naseri
# citta             Campoformido
# via        Vicolo Del pozzo 21
# Name: 233, dtype: object)
# (234, nome                   Danino
# cognome          Amuthalingam
# clean            Amuthalingam
# citta                   Udine
# via        Via San martino 18
# Name: 234, dtype: object)
# (235, nome               Iride
# cognome      Compierchio
# clean        Compierchio
# citta            Carlino
# via        Via Osoppo 14
# Name: 235, dtype: object)
# (236, nome                  Frangiotto
# cognome                  Anglano
# clean                    Anglano
# citta                      Fanna
# via        Strada Statale 464 14
# Name: 236, dtype: object)
# (237, nome                            Eddo
# cognome                      Progida
# clean                        Progida
# citta                 Pavia di udine
# via        Via San giovanni bosco 26
# Name: 237, dtype: object)
# (238, nome                 Nema
# cognome           Nimalan
# clean             Nimalan
# citta             Cormons
# via        Via Sinicco 37
# Name: 238, dtype: object)
# (239, nome                   Ligio
# cognome          Paglialonga
# clean            Paglialonga
# citta         Duino-aurisina
# via        Frazione Duino 67
# Name: 239, dtype: object)
# (240, nome                     Rosildo
# cognome                  Corrado
# clean                    Corrado
# citta                Spilimbergo
# via        Via Unita'd'italia 24
# Name: 240, dtype: object)
# (241, nome                       Grato
# cognome                     Kazi
# clean                       Kazi
# citta      Casarsa della delizia
# via               Viale Udine 19
# Name: 241, dtype: object)
# (242, nome                      Irmina
# cognome                 Consales
# clean                   Consales
# citta      Malborghetto valbruna
# via               Via Saisera 65
# Name: 242, dtype: object)
# (243, nome           Norberto
# cognome         Ruberti
# clean           Ruberti
# citta           Zoppola
# via        Via Piave 32
# Name: 243, dtype: object)
# (244, nome                    Umbertino
# cognome                   Gurrera
# clean                     Gurrera
# citta      Palazzolo dello stella
# via            Casali Moretton 23
# Name: 244, dtype: object)
# (245, nome                        Anto
# cognome                  Zlateva
# clean                    Zlateva
# citta                   Lusevera
# via        Frazione Pradielis 54
# Name: 245, dtype: object)
# (246, nome                 Orea
# cognome         Polignano
# clean           Polignano
# citta              Caneva
# via        Via Pradego 84
# Name: 246, dtype: object)
# (247, nome           Andreuccia
# cognome          Bellitti
# clean            Bellitti
# citta         Mortegliano
# via        Via Marconi 24
# Name: 247, dtype: object)
# (248, nome                Sipontina
# cognome         Kaligu ralage
# clean           Kaligu ralage
# citta                   Lauco
# via        Frazione Buttea 41
# Name: 248, dtype: object)
# (249, nome                     Sestilia
# cognome                   Marando
# clean                     Marando
# citta                      Muggia
# via        Localita  Fontanella 8
# Name: 249, dtype: object)
# (250, nome              Tolmino
# cognome        Carofiglio
# clean          Carofiglio
# citta             Trieste
# via        Via Lucrezio 2
# Name: 250, dtype: object)
# (251, nome                   Arcido
# cognome              Laggetta
# clean                Laggetta
# citta       Gemona del friuli
# via        Via Cjarnescule 72
# Name: 251, dtype: object)
# (252, nome                       Goita
# cognome                    Calvo
# clean                      Calvo
# citta                     Aviano
# via        Via Arturo ferrucci 9
# Name: 252, dtype: object)
# (253, nome              Lice
# cognome        Mahboob
# clean          Mahboob
# citta       Arta terme
# via        Via Lovea 0
# Name: 253, dtype: object)
# (254, nome                Miriano
# cognome                Conz
# clean                  Conz
# citta                 Resia
# via        Via Progresso 11
# Name: 254, dtype: object)
# (255, nome                  Armelindo
# cognome                 D'alema
# clean                   D alema
# citta                   Artegna
# via        Via Sottocastello 13
# Name: 255, dtype: object)
# (256, nome                    Zilio
# cognome              La serra
# clean                La serra
# citta           Azzano decimo
# via        Via Santa croce 31
# Name: 256, dtype: object)
# (257, nome            Bonardo
# cognome     Piazzalunga
# clean       Piazzalunga
# citta         Cordenons
# via        Via Rigolo 3
# Name: 257, dtype: object)
# (258, nome             Diodora
# cognome       Pontoriero
# clean         Pontoriero
# citta      Fontanafredda
# via        Via Quarto 12
# Name: 258, dtype: object)
# (259, nome                 Finia
# cognome           Curlante
# clean             Curlante
# citta            Cordenons
# via        Via G. rossi 16
# Name: 259, dtype: object)
# (260, nome             Olivenza
# cognome          Sonnessa
# clean            Sonnessa
# citta                Ruda
# via        Via Gorizia 38
# Name: 260, dtype: object)
# (261, nome                         Conina
# cognome                   Casilebbe
# clean                     Casilebbe
# citta                       Trieste
# via        Viale Dei campi elisi 29
# Name: 261, dtype: object)
# (262, nome                     Eden
# cognome                   Sow
# clean                     Sow
# citta      Lignano sabbiadoro
# ...
# via        Piazzale Castello 9
# Name: 4920, dtype: object)
# (4921, nome            Nunziante
# cognome           Jackson
# clean             Jackson
# citta           Palmanova
# via        Via Cairoli 12
# Name: 4921, dtype: object)
# (4922, nome                    Palmino
# cognome               Sparascio
# clean                 Sparascio
# citta                 Polcenigo
# via        Localita  Boscadel 9
# Name: 4922, dtype: object)
# (4923, nome             Alcido
# cognome      Rajaseelan
# clean        Rajaseelan
# citta           Sequals
# via        Via Verdi 15
# Name: 4923, dtype: object)
# (4924, nome                     Armela
# cognome              Varegliano
# clean                Varegliano
# citta                   Gorizia
# via        Via Terza armata 183
# Name: 4924, dtype: object)
# (4925, nome                            Casta
# cognome                      Massagli
# clean                        Massagli
# citta          San daniele del friuli
# via        Via Fratelli pischiutta 53
# Name: 4925, dtype: object)
# (4926, nome                   Ostilide
# cognome              Thangavelu
# clean                Thangavelu
# citta                  Codroipo
# via        Via Dei cacciatori 4
# Name: 4926, dtype: object)
# (4927, nome           Crescenza
# cognome       Carpinello
# clean         Carpinello
# citta      Forni avoltri
# via        Via Corona 24
# Name: 4927, dtype: object)
# (4928, nome                 Feranda
# cognome                Csiki
# clean                  Csiki
# citta      Gemona del friuli
# via             Via Campo 62
# Name: 4928, dtype: object)
# (4929, nome             Fiorenzio
# cognome            Cobovic
# clean              Cobovic
# citta             Brugnera
# via        Via Carriade 26
# Name: 4929, dtype: object)
# (4930, nome                      Nora
# cognome                 Carlin
# clean                   Carlin
# citta                  Gorizia
# via        Via Dei grabizio 17
# Name: 4930, dtype: object)
# (4931, nome              Corinto
# cognome           Galuppo
# clean             Galuppo
# citta            Tarcento
# via        Via D.manin 24
# Name: 4931, dtype: object)
# (4932, nome                      Adiutore
# cognome                 Di giorgio
# clean                   Di giorgio
# citta      San vito al tagliamento
# via                 Via Codizze 13
# Name: 4932, dtype: object)
# (4933, nome                        Alferino
# cognome                      Buiatti
# clean                        Buiatti
# citta            Cividale del friuli
# via        Via Gioacchino rossini 13
# Name: 4933, dtype: object)
# (4934, nome                     Leonello
# cognome                   Baglivo
# clean                     Baglivo
# citta                     Trieste
# via        Via Brigata casale 157
# Name: 4934, dtype: object)
# (4935, nome                    Odelio
# cognome               D'agosta
# clean                 D agosta
# citta          Mereto di tomba
# via        Via Duca d'aosta 27
# Name: 4935, dtype: object)
# (4936, nome                     Aldegardo
# cognome                  Savastano
# clean                    Savastano
# citta            Tramonti di sopra
# via        Via Tramonti di sotto 3
# Name: 4936, dtype: object)
# (4937, nome                   Florestano
# cognome                     Kante
# clean                       Kante
# citta      San daniele del friuli
# via           Via Nussio nussi 10
# Name: 4937, dtype: object)
# (4938, nome                Sigifredo
# cognome               Otranto
# clean                 Otranto
# citta                   Udine
# via        Via Soffumbergo 22
# Name: 4938, dtype: object)
# (4939, nome                          Onelia
# cognome                    Matarrese
# clean                      Matarrese
# citta      Colloredo di monte albano
# via                 Via Sottocolle 5
# Name: 4939, dtype: object)
# (4940, nome                      Ciro
# cognome              Chiavacci
# clean                Chiavacci
# citta                  Trieste
# via        Via Di basovizza 30
# Name: 4940, dtype: object)
# (4941, nome          Giovandamiano
# cognome            Mogavero
# clean              Mogavero
# citta         Azzano decimo
# via        Via Ronchiate 25
# Name: 4941, dtype: object)
# (4942, nome                           Zeila
# cognome                Mohamed sabri
# clean                  Mohamed sabri
# citta                          Udine
# via        Via Francesco di toppo 45
# Name: 4942, dtype: object)
# (4943, nome                  Fidelmo
# cognome                  Cici
# clean                    Cici
# citta                  Sacile
# via        Strada Vistorta 68
# Name: 4943, dtype: object)
# (4944, nome              Massimiliano
# cognome                Ocarino
# clean                  Ocarino
# citta                 Pagnacco
# via        Via Dei platani 118
# Name: 4944, dtype: object)
# (4945, nome                   Giuseppa
# cognome                      Ju
# clean                        Ju
# citta       Cividale del friuli
# via        Via Elio morpurgo 18
# Name: 4945, dtype: object)
# (4946, nome                     Superia
# cognome              Castelnuovo
# clean                Castelnuovo
# citta                 Monfalcone
# via        Via Dei bagni nuova 5
# Name: 4946, dtype: object)
# (4947, nome                Libico
# cognome    Messeni nemagna
# clean      Messeni nemagna
# citta      Pasian di prato
# via         Via Liguria 15
# Name: 4947, dtype: object)
# (4948, nome              Quartilla
# cognome           Sanfelice
# clean             Sanfelice
# citta        Pavia di udine
# via        Via Palmanova 36
# Name: 4948, dtype: object)
# (4949, nome               Anda
# cognome            Lika
# clean              Lika
# citta         Tricesimo
# via        Via Gemona 9
# Name: 4949, dtype: object)
# (4950, nome                       Doralba
# cognome                  Portolano
# clean                    Portolano
# citta            Gemona del friuli
# via        Via Pre bepo marchet 40
# Name: 4950, dtype: object)
# (4951, nome               Fasma
# cognome           Corini
# clean             Corini
# citta              Udine
# via        Via Timavo 12
# Name: 4951, dtype: object)
# (4952, nome            Laurina
# cognome      Alessandri
# clean        Alessandri
# citta             Ovaro
# via        Via Cella 35
# Name: 4952, dtype: object)
# (4953, nome                       Etrusca
# cognome                  Marchiori
# clean                    Marchiori
# citta         Ronchi dei legionari
# via        Via Brigata macerata 14
# Name: 4953, dtype: object)
# (4954, nome                   Agnesio
# cognome         Liberti merico
# clean           Liberti merico
# citta                 Brugnera
# via        Via Ss. trinita' 61
# Name: 4954, dtype: object)
# (4955, nome                    Rosalbino
# cognome                    Chhipa
# clean                      Chhipa
# citta      San daniele del friuli
# via                 Via Majano 17
# Name: 4955, dtype: object)
# (4956, nome              Allegra
# cognome            Garzya
# clean              Garzya
# citta            Tarcento
# via        Via Nogaria 16
# Name: 4956, dtype: object)
# (4957, nome               Raffele
# cognome           Tirabovi
# clean             Tirabovi
# citta                Udine
# via        Via Del bon 348
# Name: 4957, dtype: object)
# (4958, nome                        Brizia
# cognome                      Manta
# clean                        Manta
# citta                     Latisana
# via        Via Leonardo da vinci 7
# Name: 4958, dtype: object)
# (4959, nome             Rizzerio
# cognome            Ragone
# clean              Ragone
# citta          Cercivento
# via        Via Taviele 14
# Name: 4959, dtype: object)
# (4960, nome                 Fortunina
# cognome                Marsini
# clean                  Marsini
# citta                  Trieste
# via        Via Fabio severo 42
# Name: 4960, dtype: object)
# (4961, nome               Redente
# cognome            Maddalo
# clean              Maddalo
# citta                Udine
# via        Via Mantova 108
# Name: 4961, dtype: object)
# (4962, nome                    Eufrasina
# cognome                Sathasivam
# clean                  Sathasivam
# citta                     Trieste
# via        Strada Per longera 244
# Name: 4962, dtype: object)
# (4963, nome              Bertillo
# cognome             Aliffi
# clean               Aliffi
# citta               Porcia
# via        Via Bagnador 33
# Name: 4963, dtype: object)
# (4964, nome                       Ermogene
# cognome                     Garside
# clean                       Garside
# citta         San giorgio di nogaro
# via        Via Fratelli sguazzin 12
# Name: 4964, dtype: object)
# (4965, nome                     Sabotino
# cognome       Schuaman campoverde
# clean         Schuaman campoverde
# citta                     Maniago
# via        Via Vittorio alfieri 7
# Name: 4965, dtype: object)
# (4966, nome            Valchirio
# cognome        D'ippolito
# clean          D ippolito
# citta           Pordenone
# via        Viale Grande 8
# Name: 4966, dtype: object)
# (4967, nome                   Enedina
# cognome               Vascotto
# clean                 Vascotto
# citta       Prata di pordenone
# via        Calle Delle oche 14
# Name: 4967, dtype: object)
# (4968, nome                  Ciretta
# cognome                 Medde
# clean                   Medde
# citta                 Buttrio
# via        Via P.m.d'aviano 4
# Name: 4968, dtype: object)
# (4969, nome              Nardina
# cognome           Forcina
# clean             Forcina
# citta           Tricesimo
# via        Via I. nievo 3
# Name: 4969, dtype: object)
# (4970, nome                        Oscardo
# cognome                      Manara
# clean                        Manara
# citta      San giovanni al natisone
# via             Via G. b. donato 49
# Name: 4970, dtype: object)
# (4971, nome                  Alan
# cognome      Moro quaranta
# clean        Moro quaranta
# citta            Pordenone
# via        Via Revedole 43
# Name: 4971, dtype: object)
# (4972, nome                  Paolo
# cognome            Ponzetta
# clean              Ponzetta
# citta                Porcia
# via        Via Rustighel 75
# Name: 4972, dtype: object)
# (4973, nome       Monserrato
# cognome       Iannace
# clean         Iannace
# citta           Udine
# via         Via Po 42
# Name: 4973, dtype: object)
# (4974, nome                   Nivea
# cognome         Moore haines
# clean           Moore haines
# citta                 Caneva
# via        Via Xxv aprile 52
# Name: 4974, dtype: object)
# (4975, nome              Fidalmino
# cognome            Scandura
# clean              Scandura
# citta                 Udine
# via        Via Tavagnacco 3
# Name: 4975, dtype: object)
# (4976, nome                    Artemisia
# cognome                Annunziata
# clean                  Annunziata
# citta      San pietro al natisone
# via             Via Alpe adria 46
# Name: 4976, dtype: object)
# (4977, nome             Santoro
# cognome              Lan
# clean                Lan
# citta               Ruda
# via        Via Ampezzo 1
# Name: 4977, dtype: object)
# (4978, nome                    Gemisto
# cognome                    Cela
# clean                      Cela
# citta          Savogna d'isonzo
# via        Via Gaudenzio tosi 4
# Name: 4978, dtype: object)
# (4979, nome              Romolino
# cognome    Bahia alindogan
# clean      Bahia alindogan
# citta        Treppo grande
# via           Via Dante 31
# Name: 4979, dtype: object)
# (4980, nome                       Isotto
# cognome                 Tirnavean
# clean                   Tirnavean
# citta                    Codroipo
# via        Via Divisione julia 18
# Name: 4980, dtype: object)
# (4981, nome                   Delina
# cognome           Quintavalle
# clean             Quintavalle
# citta               Pordenone
# via        Largo Cervignano 8
# Name: 4981, dtype: object)
# (4982, nome                   Zanino
# cognome                Harrak
# clean                  Harrak
# citta      Castions di strada
# via               Via Roma 47
# Name: 4982, dtype: object)
# (4983, nome                   Fabiana
# cognome                Zizzari
# clean                  Zizzari
# citta                  Trieste
# via        Via Pasteur louis 9
# Name: 4983, dtype: object)
# (4984, nome                        Varo
# cognome                     Dego
# clean                       Dego
# citta                   Drenchia
# via        Localita  Obenetto 21
# Name: 4984, dtype: object)
# (4985, nome              Lombardo
# cognome           Casavola
# clean             Casavola
# citta              Dignano
# via        Via Di sotto 26
# Name: 4985, dtype: object)
# (4986, nome                   Admeto
# cognome                Tereba
# clean                  Tereba
# citta                 Manzano
# via        Via Poggiobello 15
# Name: 4986, dtype: object)
# (4987, nome                    Adelmino
# cognome                   Scacco
# clean                     Scacco
# citta      Montereale valcellina
# via             Via Montenero 43
# Name: 4987, dtype: object)
# (4988, nome                   Amanda
# cognome         Arunakirirasa
# clean           Arunakirirasa
# citta               Pordenone
# via        Via San quirino 25
# Name: 4988, dtype: object)
# (4989, nome                Balbina
# cognome               Regis
# clean                 Regis
# citta                  Buja
# via        Via Cjadreã”r 19
# Name: 4989, dtype: object)
# (4990, nome                 Aurelia
# cognome           Di gregoli
# clean             Di gregoli
# citta                 Sutrio
# via        Via Liberazione 8
# Name: 4990, dtype: object)
# (4991, nome                     Clodoveo
# cognome                  Scaletta
# clean                    Scaletta
# citta                     Ragogna
# via        Via Vittorio veneto 23
# Name: 4991, dtype: object)
# (4992, nome                 Quarto
# cognome          Blandolino
# clean            Blandolino
# citta               Pulfero
# via        Via Zapatocco 47
# Name: 4992, dtype: object)
# (4993, nome                   Amonastro
# cognome            Mohamed zinan
# clean              Mohamed zinan
# citta          Gemona del friuli
# via        Via Pace da gemona 10
# Name: 4993, dtype: object)
# (4994, nome            Girolamo
# cognome        Muttickal
# clean          Muttickal
# citta         Cercivento
# via        Via Di sot 63
# Name: 4994, dtype: object)
# (4995, nome              Arduina
# cognome            Palano
# clean              Palano
# citta       Azzano decimo
# via        Via Trieste 29
# Name: 4995, dtype: object)
# (4996, nome              Mafalda
# cognome         Del vento
# clean           Del vento
# citta            Latisana
# via        Via Ronchis 42
# Name: 4996, dtype: object)
# (4997, nome                  Aquila
# cognome               Enache
# clean                 Enache
# citta          Azzano decimo
# via        Via G. marconi 37
# Name: 4997, dtype: object)
# (4998, nome                           Rodano
# cognome                     Tarantino
# clean                       Tarantino
# citta                         Gorizia
# via        Via Pier andrea mattioli 3
# Name: 4998, dtype: object)
# (4999, nome              Epimenio
# cognome              Merlo
# clean                Merlo
# citta                 Teor
# via        Casali Volta 14
# Name: 4999, dtype: object)
# [{'nome': 'Fidarma', 'cognome': 'Solombrino', 'codiceFiscale': 'SOIFIM33U20Q912N', 'citta': 'Maniago', 'via': 'Via Tiziano vecellio 32'}, {'nome': 'Portos', 'cognome': 'Greco', 'codiceFiscale': 'GROPOT28U08E502Y', 'citta': 'Cervignano del friuli', 'via': 'Piazza Guglielmo marconi 14'}, {'nome': 'Quinzia', 'cognome': 'Tunwal', 'codiceFiscale': 'TUWQUZ78N29U115A', 'citta': 'Travesio', 'via': 'Via Forchiat 11'}, {'nome': 'Rinda', 'cognome': 'Arcidiacona', 'codiceFiscale': 'ARRRID59I33E601X', 'citta': 'Arzene', 'via': 'Via Maiaroff 7'}, {'nome': 'Miroslao', 'cognome': 'Caporale', 'codiceFiscale': 'CALMIA96R30J564F', 'citta': 'Capriva del friuli', 'via': 'Via I maggio 12'}, {'nome': 'Iliana', 'cognome': 'Diana', 'codiceFiscale': 'DINILA85R07F804T', 'citta': 'Udine', 'via': 'Via Pozzuolo 8'}, {'nome': 'Cosimino', 'cognome': 'Alarcio', 'codiceFiscale': 'ALOCOI47G38E715T', 'citta': 'Udine', 'via': 'Via Prospero antonini 1'}, {'nome': 'Elfride', 'cognome': 'Rollo', 'codiceFiscale': 'ROOELR67P13T617P', 'citta': 'Porpetto', 'via': 'Via Roma 1'}, {'nome': 'Gradita', 'cognome': 'Anastasio', 'codiceFiscale': 'ANIGRD30N04O833O', 'citta': 'Spilimbergo', 'via': "Via Duca d'aosta 3"}, {'nome': 'Sabina', 'cognome': 'Ananika', 'codiceFiscale': 'ANNSAN04M30V992Y', 'citta': 'Aviano', 'via': 'Vicolo San martino 4'}]

# %%
import csv

with open('CSV/dati_anagrafici_clienti.csv', mode='w',newline='', encoding='utf-8') as client_file:
    client_writer = csv.writer(client_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    
    for dati in dati_anagrafici:
        client_writer.writerow([dati["nome"],dati["cognome"],dati["codiceFiscale"],dati['citta'],dati['via']])
